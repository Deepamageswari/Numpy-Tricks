# %%
import pandas as pa # python package...data analysis
import numpy
import seaborn
# filtering...pandas...
# matplotlib.pyplot as plt--> just for


# cleaning the data
# visualizing the data
# processing the data
# transforming the data

# %%
# steps in data science project...
....loading the data... in your python environment...
....describe()...descriptive statistics...max,min,ad,...
.... filter out or boolean indexing to understand our data
....visualize the data...
        2 dim plop
    ... scatterplot.... dot plot....x and y axis...
       ...line plop....
        ...histogram...
        ....bar plot...
        ...box plop....
    ... check out statistics... hypothesis testing .. on our data... assumption...
    ...check which model to use for prediction...
    ...apply machinlearning to the data...
    ...accuracy of your model..
     if model is performing well.. retain that model...
        other if accuracy is bad.. with this model...
        then apply another ml model ... checl... accuracy of that model...

# %%
print(dir(seaborn))
# Out:
# ['FacetGrid', 'JointGrid', 'PairGrid', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_core', '_decorators', '_docstrings', '_orig_rc_params', '_statistics', 'algorithms', 'axes_style', 'axisgrid', 'barplot', 'blend_palette', 'boxenplot', 'boxplot', 'categorical', 'catplot', 'choose_colorbrewer_palette', 'choose_cubehelix_palette', 'choose_dark_palette', 'choose_diverging_palette', 'choose_light_palette', 'clustermap', 'cm', 'color_palette', 'colors', 'countplot', 'crayon_palette', 'crayons', 'cubehelix_palette', 'dark_palette', 'desaturate', 'despine', 'displot', 'distplot', 'distributions', 'diverging_palette', 'dogplot', 'ecdfplot', 'external', 'factorplot', 'get_data_home', 'get_dataset_names', 'heatmap', 'histplot', 'hls_palette', 'husl_palette', 'jointplot', 'kdeplot', 'light_palette', 'lineplot', 'lmplot', 'load_dataset', 'matrix', 'miscplot', 'mpl', 'mpl_palette', 'pairplot', 'palettes', 'p
# ...

# %%
fortune=pandas.read_csv('f500.csv')

# %%
fortune

# %%
type(fortune)
# Out:
# pandas.core.frame.DataFrame

# %%
# python data analysis library - pandas
pandas
1.mean
2.median
3.mode
4.standard Deviation
5.Q1,Q2,Q3
6.min,max
# Out:
#   File "<ipython-input-6-18c9f08749ed>", line 3
#     1.mean
#       ^
# SyntaxError: invalid syntax

# %%
rev=fortune['revenues']

# %%
# mean calculation
rev.mean()
# Out:
# 55416.358

# %%
rev.max()
# Out:
# 485873

# %%
rev.min()
# Out:
# 21609

# %%
rev.mode()
# Out:
# 0    23044
# 1    29003
# 2    30390
# dtype: int64

# %%
rev.describe()
# Out:
# count       500.000000
# mean      55416.358000
# std       45725.478963
# min       21609.000000
# 25%       29003.000000
# 50%       40236.000000
# 75%       63926.750000
# max      485873.000000
# Name: revenues, dtype: float64

# %%
fortune
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
sec=fortune['sector']

# %%
sec.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-fb04933fbe9f> in <module>
# ----> 1 sec.unique()
#
# NameError: name 'sec' is not defined

# %%
len(sec.unique())
# Out:
# 21

# %%
ind=fortune['industry']

# %%
ind.unique()
# Out:
# array(['General Merchandisers', 'Utilities', 'Petroleum Refining',
#        'Motor Vehicles and Parts',
#        'Insurance: Property and Casualty (Stock)',
#        'Computers, Office Equipment', 'Wholesalers: Health Care',
#        'Health Care: Insurance and Managed Care',
#        'Health Care: Pharmacy and Other Services',
#        'Electronics, Electrical Equip.', 'Mining, Crude-Oil Production',
#        'Telecommunications', 'Diversified Financials',
#        'Banks: Commercial and Savings', 'Engineering, Construction',
#        'Insurance: Life, Health (stock)',
#        'Internet Services and Retailing', 'Industrial Machinery',
#        'Food and Drug Stores', 'Trading', 'Specialty Retailers',
#        'Aerospace and Defense', 'Energy', 'Food Consumer Products',
#        'Computer Software', 'Information Technology Services',
#        'Network and Other Communications Equipment',
#        'Insurance: Property and Casualty (Mutual)', 'Pharmaceuticals',
# ...

# %%
len(ind.unique())
# Out:
# 58

# %%
# boolean indexing-it is used to filter out 
fortune[0:5]
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
fortune['company'][0:5]
# Out:
# 0                     Walmart
# 1                  State Grid
# 2               Sinopec Group
# 3    China National Petroleum
# 4                Toyota Motor
# Name: company, dtype: object

# %%
fortune['company'][495:500]
# Out:
# 495    Teva Pharmaceutical Industries
# 496          New China Life Insurance
# 497         Wm. Morrison Supermarkets
# 498                               TUI
# 499                        AutoNation
# Name: company, dtype: object

# %%
fortune['company'][5:11]
# Out:
# 5             Volkswagen
# 6      Royal Dutch Shell
# 7     Berkshire Hathaway
# 8                  Apple
# 9            Exxon Mobil
# 10              McKesson
# Name: company, dtype: object

# %%
fortune['company'][101]
# Out:
# 'Lukoil'

# %%
fortune['company'][49]
# Out:
# 'Nippon Telegraph & Telephone'

# %%
fortune['company'][49:51]
# Out:
# 49    Nippon Telegraph & Telephone
# 50            China Life Insurance
# Name: company, dtype: object

# %%
cou=fortune['country']

# %%
cou
# Out:
# 0          USA
# 1        China
# 2        China
# 3        China
# 4        Japan
#         ...
# 495     Israel
# 496      China
# 497    Britain
# 498    Germany
# 499        USA
# Name: country, Length: 500, dtype: object

# %%
fortune['country'].value_counts()
# Out:
# USA             132
# China           109
# Japan            51
# Germany          29
# France           29
# Britain          24
# South Korea      15
# Switzerland      14
# Netherlands      14
# Canada           11
# Spain             9
# Brazil            7
# Australia         7
# India             7
# Italy             7
# Taiwan            6
# Ireland           4
# Russia            4
# Sweden            3
# Singapore         3
# Mexico            2
# Israel            1
# Belgium           1
# Venezuela         1
# Indonesia         1
# Malaysia          1
# Saudi Arabia      1
# Finland           1
# Denmark           1
# Thailand          1
# U.A.E             1
# Luxembourg        1
# Turkey            1
# Norway            1
# Name: country, dtype: int64

# %%
cou
# Out:
# 0          USA
# 1        China
# 2        China
# 3        China
# 4        Japan
#         ...
# 495     Israel
# 496      China
# 497    Britain
# 498    Germany
# 499        USA
# Name: country, Length: 500, dtype: object

# %%
# cou.unique()

# %%
len(cou.unique())
# Out:
# 34

# %%
rev=fortune['revenues']

# %%
rev.mean()
# Out:
# 55416.358

# %%
# boolean indexing...

# logical operators...and ...list functon...
# all the companies rows which have earned revenue less thae average...mean
fortune['revenues']<=rev.mean()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495     True
# 496     True
# 497     True
# 498     True
# 499     True
# Name: revenues, Length: 500, dtype: bool

# %%
fortune[fortune['revenues']<=rev.mean()]
# Out:
#                               company  rank  revenues  revenue_change  \
# 161  Aviation Industry Corp. of China   162     55306            -8.2
# 162                         ING Group   163     55282           -16.5
# 163    Mitsubishi UFJ Financial Group   164     55185            15.9
# 164              Royal Ahold Delhaize   165     54955            29.7
# 165                            Humana   166     54379             0.2
# ..                                ...   ...       ...             ...
# 495    Teva Pharmaceutical Industries   496     21903            11.5
# 496          New China Life Insurance   497     21796           -13.3
# 497         Wm. Morrison Supermarkets   498     21741           -11.3
# 498                               TUI   499     21655            -5.5
# 499                        AutoNation   500     21609             3.6
#
#      profits   assets  profit_change                 ceo  \
# 161    464.2   124892          -47.4         Tan Ruisong
# ...

# %%
fortune['revenues'].min()
# Out:
# 21609

# %%
fortune['revenues']==fortune['revenues'].min()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499     True
# Name: revenues, Length: 500, dtype: bool

# %%
fortune[fortune['revenues']==fortune['revenues'].min()]
# Out:
#         company  rank  revenues  revenue_change  profits  assets  \
# 499  AutoNation   500     21609             3.6    430.5   10060
#
#      profit_change                 ceo             industry     sector  \
# 499           -2.7  Michael J. Jackson  Specialty Retailers  Retailing
#
#      previous_rank country          hq_location                    website  \
# 499              0     USA  Fort Lauderdale, FL  http://www.autonation.com
#
#      years_on_global_500_list  employees  total_stockholder_equity
# 499                        12      26000                      2310

# %%
fortune[fortune['revenues']==fortune['revenues'].max()]
# Out:
#    company  rank  revenues  revenue_change  profits  assets  profit_change  \
# 0  Walmart     1    485873             0.8  13643.0  198825           -7.2
#
#                    ceo               industry     sector  previous_rank  \
# 0  C. Douglas McMillon  General Merchandisers  Retailing              1
#
#   country      hq_location                 website  years_on_global_500_list  \
# 0     USA  Bentonville, AR  http://www.walmart.com                        23
#
#    employees  total_stockholder_equity
# 0    2300000                     77798

# %%
pro=fortune['profits']

# %%
pro.mean()
# Out:
# 3055.203206412828

# %%
fortune['profits']<=pro.mean()
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 495     True
# 496     True
# 497     True
# 498     True
# 499     True
# Name: profits, Length: 500, dtype: bool

# %%
fortune[fortune['profits']==fortune['profits'].max()]
# Out:
#   company  rank  revenues  revenue_change  profits  assets  profit_change  \
# 8   Apple     9    215639            -7.7  45687.0  321686          -14.4
#
#                ceo                     industry      sector  previous_rank  \
# 8  Timothy D. Cook  Computers, Office Equipment  Technology              9
#
#   country    hq_location               website  years_on_global_500_list  \
# 8     USA  Cupertino, CA  http://www.apple.com                        15
#
#    employees  total_stockholder_equity
# 8     116000                    128249

# %%
# find the  top 10 revenues earning companies names... and revenues...
fortune[fortune['revenues']==fortune['revenues'].max()]
# Out:
#    company  rank  revenues  revenue_change  profits  assets  profit_change  \
# 0  Walmart     1    485873             0.8  13643.0  198825           -7.2
#
#                    ceo               industry     sector  previous_rank  \
# 0  C. Douglas McMillon  General Merchandisers  Retailing              1
#
#   country      hq_location                 website  years_on_global_500_list  \
# 0     USA  Bentonville, AR  http://www.walmart.com                        23
#
#    employees  total_stockholder_equity
# 0    2300000                     77798

# %%
fortune['profits'].sort_values(ascending=False)[0:10]
# Out:
# 8     45687.0
# 21    41883.9
# 27    34840.9
# 37    27687.8
# 41    24773.4
# 47    24733.0
# 7     24074.0
# 60    21938.0
# 64    19478.0
# 14    19316.5
# Name: profits, dtype: float64

# %%
fortune['assets'].sort_values(ascending=True)[0:10]
# Out:
# 294    3717
# 456    4982
# 401    5413
# 438    6093
# 308    6921
# 486    7426
# 411    7932
# 474    8945
# 402    9292
# 488    9362
# Name: assets, dtype: int64

# %%
fortune['profits'].describe()
# Out:
# count      499.000000
# mean      3055.203206
# std       5171.981071
# min     -13038.000000
# 25%        556.950000
# 50%       1761.600000
# 75%       3954.000000
# max      45687.000000
# Name: profits, dtype: float64

# %%
fortune[fortune['profits']>=19316.5]
# Out:
#                                   company  rank  revenues  revenue_change  \
# 7                      Berkshire Hathaway     8    223604             6.1
# 8                                   Apple     9    215639            -7.7
# 14                    Samsung Electronics    15    173957            -2.0
# 21  Industrial & Commercial Bank of China    22    147675           -11.7
# 27                China Construction Bank    28    135093            -8.7
# 37             Agricultural Bank of China    38    117275           -12.1
# 41                          Bank of China    42    113708            -7.1
# 47                      J.P. Morgan Chase    48    105486             4.4
# 60                            Wells Fargo    61     94176             4.6
# 64                               Alphabet    65     90272            20.4
#
#     profits   assets  profit_change                ceo  \
# 7   24074.0   620854            NaN  Warren E. Buffett
# ...

# %%
print('naveen reddy you tube vedios')
# Out:
# naveen reddy you tube vedios

# %%
fortune['assets']
# Out:
# 0      198825
# 1      489838
# 2      310726
# 3      585619
# 4      437575
#         ...
# 495     92890
# 496    100609
# 497     11630
# 498     16247
# 499     10060
# Name: assets, Length: 500, dtype: int64

# %%
fortune['assets']
# Out:
# 0      198825
# 1      489838
# 2      310726
# 3      585619
# 4      437575
#         ...
# 495     92890
# 496    100609
# 497     11630
# 498     16247
# 499     10060
# Name: assets, Length: 500, dtype: int64

# %%
fortune[fortune['assets']==fortune['assets'].max()]
# Out:
#                                   company  rank  revenues  revenue_change  \
# 21  Industrial & Commercial Bank of China    22    147675           -11.7
#
#     profits   assets  profit_change     ceo                       industry  \
# 21  41883.9  3473238           -5.0  Gu Shu  Banks: Commercial and Savings
#
#         sector  previous_rank country     hq_location  \
# 21  Financials             15   China  Beijing, China
#
#                     website  years_on_global_500_list  employees  \
# 21  http://www.icbc-ltd.com                        19     461749
#
#     total_stockholder_equity
# 21                    283438

# %%
fortune['assets'].mean()
# Out:
# 243632.274

# %%
fortune['assets'].min()
# Out:
# 3717

# %%
fortune[fortune['assets']==fortune['assets'].min()]
# Out:
#             company  rank  revenues  revenue_change  profits  assets  \
# 294  Rajesh Exports   295     36114            43.1    185.8    3717
#
#      profit_change              ceo industry       sector  previous_rank  \
# 294           13.8  Rajesh J. Mehta  Trading  Wholesalers            423
#
#     country       hq_location                     website  \
# 294   India  Bengaluru, India  http://www.rajeshindia.com
#
#      years_on_global_500_list  employees  total_stockholder_equity
# 294                         2        328                       868

# %%
fortune['assets'][290:296]
# Out:
# 290    920291
# 291    764712
# 292     28299
# 293     49205
# 294      3717
# 295     13776
# Name: assets, dtype: int64

# %%
fortune[fortune['assets']>=fortune['assets'].min()][290:295]
# Out:
#                          company  rank  revenues  revenue_change  profits  \
# 290                    UBS Group   291     36230            -5.9   3252.2
# 291              Intesa Sanpaolo   292     36225           -14.2   3440.3
# 292                George Weston   293     36211            -1.3    414.9
# 293  Mitsubishi Heavy Industries   294     36122             7.2    809.6
# 294               Rajesh Exports   295     36114            43.1    185.8
#
#      assets  profit_change                ceo                       industry  \
# 290  920291          -49.6  Sergio P. Ermotti  Banks: Commercial and Savings
# 291  764712           13.2      Carlo Messina  Banks: Commercial and Savings
# 292   28299            0.6    Galen G. Weston           Food and Drug Stores
# 293   49205           52.3  Shunichi Miyanaga           Industrial Machinery
# 294    3717           13.8    Rajesh J. Mehta                        Trading
#
# ...

# %%
fortune['assets'].sort_values(ascending=True)[0:10]
# Out:
# 294    3717
# 456    4982
# 401    5413
# 438    6093
# 308    6921
# 486    7426
# 411    7932
# 474    8945
# 402    9292
# 488    9362
# Name: assets, dtype: int64

# %%
fortune[fortune['assets']<=9362].sort_values(by='assets',ascending=False)[0:10]
# Out:
#                                 company  rank  revenues  revenue_change  \
# 488                      Sears Holdings   489     22138           -12.0
# 402                Phoenix Pharmahandel   403     26976             5.2
# 474                    US Foods Holding   475     22919            -0.9
# 411                           Tech Data   412     26235            -0.5
# 486                   Ultrapar Holdings   487     22167            -2.3
# 308                      Edeka Zentrale   309     34193             6.8
# 438  China National Aviation Fuel Group   439     24588            11.3
# 401                 World Fuel Services   402     27016           -11.1
# 456                     Heraeus Holding   457     23793            65.9
# 294                      Rajesh Exports   295     36114            43.1
#
#      profits  assets  profit_change                  ceo  \
# 488  -2221.0    9362            NaN    Edward S. Lampert
# 402    135.4    9292          -39.5      Oliver Windholz
# ...

# %%
hi
# Out:
#                                 company  rank  revenues  revenue_change  \
# 294                      Rajesh Exports   295     36114            43.1
# 308                      Edeka Zentrale   309     34193             6.8
# 401                 World Fuel Services   402     27016           -11.1
# 402                Phoenix Pharmahandel   403     26976             5.2
# 411                           Tech Data   412     26235            -0.5
# 438  China National Aviation Fuel Group   439     24588            11.3
# 456                     Heraeus Holding   457     23793            65.9
# 474                    US Foods Holding   475     22919            -0.9
# 486                   Ultrapar Holdings   487     22167            -2.3
# 488                      Sears Holdings   489     22138           -12.0
#
#      profits  assets  profit_change                  ceo  \
# 294    185.8    3717           13.8      Rajesh J. Mehta
# 308    356.0    6921           28.3          Markus Mosa
# ...

# %%
fortune[fortune['assets']<=9362].sort_values(by='assets',ascending=True)[0:10]
# Out:
#                                 company  rank  revenues  revenue_change  \
# 294                      Rajesh Exports   295     36114            43.1
# 456                     Heraeus Holding   457     23793            65.9
# 401                 World Fuel Services   402     27016           -11.1
# 438  China National Aviation Fuel Group   439     24588            11.3
# 308                      Edeka Zentrale   309     34193             6.8
# 486                   Ultrapar Holdings   487     22167            -2.3
# 411                           Tech Data   412     26235            -0.5
# 474                    US Foods Holding   475     22919            -0.9
# 402                Phoenix Pharmahandel   403     26976             5.2
# 488                      Sears Holdings   489     22138           -12.0
#
#      profits  assets  profit_change                  ceo  \
# 294    185.8    3717           13.8      Rajesh J. Mehta
# 456      NaN    4982            NaN          Jan Rinnert
# ...

# %% [markdown]
# boolean indexing

# %%
quix is a open book

# %% [markdown]
# ##visualization...differnt typesof plots...

# %%
# matplotlib,plot...
# matlab... research field...
# matplop... visualixation...matploplib.pyplot...

# %%
import matplotlib.pyplot as plt

# %%
print(dir(plt))

# %%
fortune.head(15) #starting five rows

# %%
fortune.tail(10)

# %%
print(fortune.columns)
# Out:
# Index(['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
#        'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
#        'country', 'hq_location', 'website', 'years_on_global_500_list',
#        'employees', 'total_stockholder_equity'],
#       dtype='object')

# %%
# visualization
